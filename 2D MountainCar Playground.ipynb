# %%
# %matplotlib inline

import gym
import numpy as np
from matplotlib import pyplot as plt

# %%
env = gym.envs.make("MountainCar-v0")
# Out:
# [2017-10-24 20:36:29,648] Making new env: MountainCar-v0

# %%
state = env.reset()
print(state)
plt.figure()
plt.imshow(env.render(mode='rgb_array'))

[env.step(0) for x in range(10000)]
plt.figure()
plt.imshow(env.render(mode='rgb_array'))

env.render(close=True)
# Out:
# [-0.4416761  0.       ]
